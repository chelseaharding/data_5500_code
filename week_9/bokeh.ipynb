# %% [markdown]
# Bokeh
# Let's move on to the third library of our list. Bokeh is mainly famous for its interactive charts visualization. Bokeh renders its plots using HTML and JavaScript that uses modern web browsers for presenting elegant, concise construction of novel graphics with high-level interactivity.

# %%
# importing the modules
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.palettes import magma
import pandas as pd

# instantiating the figure object
graph = figure(title = "Bokeh Scatter Graph")

# reading the database
data = pd.read_csv("tips.csv")

# plotting the graph
graph.scatter(data['total_bill'], data['tip'], color=color, size=8, alpha=0.7)

# displaying the model
show(graph)
# Out:
#   <div id="c9b3aa27-1613-4331-8331-b2fd612a5045" data-root-id="p1968" style="display: contents;"></div>

# %% [markdown]
# Line Chart

# %%
graph_line = figure(title = "Bokeh Line Chart")

# Count of each unique value of
# tip column
df = data['tip'].value_counts()

# plotting the graph
graph_line.line(df, data['tip'])

# displaying the model
show(graph_line)
# Out:
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 123), ('y', 244)
#   <div id="dc50b7a9-4e0e-497d-9bd2-ba888fd653d3" data-root-id="p2020" style="display: contents;"></div>

# %% [markdown]
# Bar Chart

# %%
# instantiating the figure object
graph = figure(title = "Bokeh Bar Chart")

# plotting the graph
graph.vbar(data['total_bill'], top=data['tip'])

# displaying the model
show(graph)
# Out:
#   <div id="de8910ac-ad69-48b8-b098-56b098a3fa8d" data-root-id="p2072" style="display: contents;"></div>

# %% [markdown]
# Adding in Interactivity

# %%
# importing the modules
from bokeh.plotting import figure, output_file, show
import pandas as pd


# instantiating the figure object
graph = figure(title = "Bokeh Bar Chart")

# reading the database
data = pd.read_csv("tips.csv")

# plotting the graph
graph.vbar(data['total_bill'], top=data['tip'], 
           legend_label = "Bill VS Tips", color='green')

graph.vbar(data['tip'], top=data['size'], 
           legend_label = "Tips VS Size", color='red')

graph.legend.click_policy = "hide"

# displaying the model
show(graph)
# Out:
#   <div id="a78403b4-a60a-49b7-b363-7afa5c3c8724" data-root-id="p2124" style="display: contents;"></div>

# %%
from bokeh.io import show
from bokeh.models import Button, CheckboxGroup, RadioGroup, CustomJS

button = Button(label="GFG")

button.js_on_click(CustomJS(
    code="console.log('button: click!', this.toString())"))

# Labels for checkbox and radio
# buttons
L = ["First", "Second", "Third"]

# the active parameter sets checks the selected value
# by default
checkbox_group = CheckboxGroup(labels=L, active=[0, 2])

checkbox_group.js_on_click(CustomJS(code="""
    console.log('checkbox_group: active=' + this.active, this.toString())
"""))

# the active parameter sets checks the selected value
# by default
radio_group = RadioGroup(labels=L, active=1)

radio_group.js_on_click(CustomJS(code="""
    console.log('radio_group: active=' + this.active, this.toString())
"""))

show(button)
show(checkbox_group)
show(radio_group)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 17
#      13 # the active parameter sets checks the selected value
#      14 # by default
#      15 checkbox_group = CheckboxGroup(labels=L, active=[0, 2])
# ---> 17 checkbox_group.js_on_click(CustomJS(code="""
#      18     console.log('checkbox_group: active=' + this.active, this.toString())
#      19 """))
#      21 # the active parameter sets checks the selected value
#      22 # by default
#      23 radio_group = RadioGroup(labels=L, active=1)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/bokeh/core/has_props.py:425, in HasProps.__getattr__(self, name)
#     422 if isinstance(descriptor, property): # Python property
#     423     return super().__getattribute__(name)
# --> 425 self._raise_attribute_error_with_matches(name, properties)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/bokeh/core/has_props.py:438, in HasProps._raise_attribute_error_with_matches(self, name, properties)
#     434     matches, text = sorted(properties), "possible"
#     436 from ..util.strings import nice_join
# --> 438 raise AttributeError(f"unexpected attribute {name!r} to {self.__class__.__name__}, {text} attributes are {nice_join(matches)}")
#
# AttributeError: unexpected attribute 'js_on_click' to CheckboxGroup, similar attributes are js_event_callbacks
