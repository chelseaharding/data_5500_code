# %% [markdown]
# Plotnine

# %%
pip install plotnine
# Out:
# Collecting plotnine
#   Downloading plotnine-0.15.8-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: matplotlib>=3.8.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from plotnine) (3.11.1)
# Requirement already satisfied: pandas>=2.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from plotnine) (3.0.5)
# Collecting mizani~=0.14.0 (from plotnine)
#   Downloading mizani-0.14.6-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from plotnine) (2.5.1)
# Collecting scipy>=1.8.0 (from plotnine)
#   Downloading scipy-1.18.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting statsmodels>=0.14.6 (from plotnine)
#   Downloading statsmodels-0.15.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib>=3.8.0->plotnine) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib>=3.8.0->plotnine) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib>=3.8.0->plotnine) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib>=3.8.0->plotnine) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib>=3.8.0->plotnine) (26.0)
# Requirement already satisfied: pillow>=9 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib>=3.8.0->plotnine) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib>=3.8.0->plotnine) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib>=3.8.0->plotnine) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.8.0->plotnine) (1.17.0)
# Collecting patsy>=0.5.6 (from statsmodels>=0.14.6->plotnine)
#   Downloading patsy-1.0.3-py2.py3-none-any.whl.metadata (3.7 kB)
# Collecting formulaic>=1.1.0 (from statsmodels>=0.14.6->plotnine)
#   Downloading formulaic-1.2.2-py3-none-any.whl.metadata (7.0 kB)
# Collecting interface-meta>=1.2.0 (from formulaic>=1.1.0->statsmodels>=0.14.6->plotnine)
#   Downloading interface_meta-2.0.1-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: narwhals>=1.17 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from formulaic>=1.1.0->statsmodels>=0.14.6->plotnine) (2.25.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from formulaic>=1.1.0->statsmodels>=0.14.6->plotnine) (4.15.0)
# Collecting wrapt>=1.0 (from formulaic>=1.1.0->statsmodels>=0.14.6->plotnine)
#   Downloading wrapt-2.4.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (7.4 kB)
# Downloading plotnine-0.15.8-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 28.3 MB/s  0:00:00
# Downloading mizani-0.14.6-py3-none-any.whl (134 kB)
# Downloading scipy-1.18.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 39.8 MB/s  0:00:006m0:00:01
# Downloading statsmodels-0.15.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 46.2 MB/s  0:00:006m0:00:01
# Downloading formulaic-1.2.2-py3-none-any.whl (118 kB)
# Downloading interface_meta-2.0.1-py3-none-any.whl (15 kB)
# Downloading patsy-1.0.3-py2.py3-none-any.whl (233 kB)
# Downloading wrapt-2.4.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (227 kB)
# Installing collected packages: wrapt, scipy, patsy, interface-meta, mizani, formulaic, statsmodels, plotnine
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [plotnine]7/8 [plotnine]ls]
# Successfully installed formulaic-1.2.2 interface-meta-2.0.1 mizani-0.14.6 patsy-1.0.3 plotnine-0.15.8 scipy-1.18.1 statsmodels-0.15.0 wrapt-2.4.0
#
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from plotnine import * 
from plotnine.data import anscombe_quartet 

ggplot(anscombe_quartet, aes(x="x", y="y")) + geom_point()

# %%
(
    ggplot(anscombe_quartet, aes("x", "y", color="dataset"))
    + geom_point()
)

# %%
(
    ggplot(anscombe_quartet, aes("x", "y", color="dataset"))
    + geom_point()
    + facet_wrap("dataset")
)
