# %% [markdown]
# Descriptive Statistics

# %%
import pandas as pd

df = pd.read_csv("/workspaces/data_5500_code/week_7/titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.describe(100)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/generic.py:11414, in NDFrame.describe(self, percentiles, include, exclude)
#   11168 @final
#   11169 def describe(
#   11170     self,
#    (...)  11173     exclude=None,
#   11174 ) -> Self:
#   11175     """
#   11176     Generate descriptive statistics.
#   11177
#    (...)  11412     max            NaN      3.0
#   11413     """
# > 11414     return describe_ndframe(
#   11415         obj=self,
#   11416         include=include,
#   11417         exclude=exclude,
#   11418         percentiles=percentiles,
#   11419     ).__finalize__(self, method="describe")
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/methods/describe.py:83, in describe_ndframe(obj, include, exclude, percentiles)
#      55 def describe_ndframe(
#      56     *,
#      57     obj: NDFrameT,
#    (...)     60     percentiles: Sequence[float] | np.ndarray | None,
#      61 ) -> NDFrameT:
#      62     """Describe series or dataframe.
#      63
#      64     Called from pandas.core.generic.NDFrame.describe()
#    (...)     81     Dataframe or series description.
#      82     """
# ---> 83     percentiles = _refine_percentiles(percentiles)
#      85     describer: NDFrameDescriberAbstract
#      86     if obj.ndim == 1:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/methods/describe.py:367, in _refine_percentiles(percentiles)
#     364 percentiles = np.asarray(percentiles)
#     366 # get them all to be in [0, 1]
# --> 367 validate_percentile(percentiles)
#     369 # sort and check for duplicates
#     370 unique_pcts = np.unique(percentiles)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/util/_validators.py:366, in validate_percentile(q)
#     364 if q_arr.ndim == 0:
#     365     if not 0 <= q_arr <= 1:
# --> 366         raise ValueError(msg)
#     367 elif not all(0 <= qs <= 1 for qs in q_arr):
#     368     raise ValueError(msg)
#
# ValueError: percentiles should all be in the interval [0, 1]

# %%
print("Average age:", df["Age"].mean())

print("Total survivors:", df["Survived"].sum())

print("Unique ports:", df["Embarked"].unique())
# Out:
# Average age: 29.69911764705882
# Total survivors: 342
# Unique ports: <StringArray>
# ['S', 'C', 'Q', nan]
# Length: 4, dtype: str

# %% [markdown]
# Sorting DataFrames

# %%
expensive_passengers = df.sort_values(by="Fare", ascending=False)
expensive_passengers[["Name", "Fare", "Pclass"]]
# Out:
#                                    Name      Fare  Pclass
# 679  Cardeza, Mr. Thomas Drake Martinez  512.3292       1
# 258                    Ward, Miss. Anna  512.3292       1
# 737              Lesurer, Mr. Gustave J  512.3292       1
# 88           Fortune, Miss. Mabel Helen  263.0000       1
# 438                   Fortune, Mr. Mark  263.0000       1
# ..                                  ...       ...     ...
# 806              Andrews, Mr. Thomas Jr    0.0000       1
# 815                    Fry, Mr. Richard    0.0000       1
# 466               Campbell, Mr. William    0.0000       2
# 481    Frost, Mr. Anthony Wood "Archie"    0.0000       2
# 822     Reuchlin, Jonkheer. John George    0.0000       1
#
# [891 rows x 3 columns]

# %%
sorted_titanic = df.sort_values(by=["Pclass", "Name"], ascending=[True, True])
sorted_titanic[["Name", "Pclass", "Age"]]
# Out:
#                                                 Name  Pclass    Age
# 730                    Allen, Miss. Elisabeth Walton       1  29.00
# 305                   Allison, Master. Hudson Trevor       1   0.92
# 297                     Allison, Miss. Helen Loraine       1   2.00
# 498  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1  25.00
# 460                              Anderson, Mr. Harry       1  48.00
# ..                                               ...     ...    ...
# 559     de Messemaeker, Mrs. Guillaume Joseph (Emma)       3  36.00
# 286                          de Mulder, Mr. Theodore       3  30.00
# 282                        de Pelsmaeker, Mr. Alfons       3  16.00
# 153                  van Billiard, Mr. Austin Blyler       3  40.50
# 868                      van Melkebeke, Mr. Philemon       3    NaN
#
# [891 rows x 3 columns]

# %% [markdown]
# Trasposing

# %%
df.head(1).T
# Out:
#                                    0
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                             22.0
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
